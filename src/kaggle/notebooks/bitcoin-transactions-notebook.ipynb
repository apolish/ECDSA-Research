# %%
# !cp -r /kaggle/input/bitcoin-transactions/* /kaggle/working/

# %%
# !ls -lah /kaggle/working/
# Out:
# total 40K
# drwxr-xr-x 3 root root 4.0K Nov 28 20:04 .
# drwxr-xr-x 5 root root 4.0K Nov 28 20:03 ..
# -rw-r--r-- 1 root root  13K Nov 28 20:04 secp256k1.py
# -rw-r--r-- 1 root root  12K Nov 28 20:04 transactions.py
# drwxr-xr-x 2 root root 4.0K Nov 28 20:03 .virtual_documents

# %%
# !python /kaggle/working/transactions.py \
    --mode legacy \
    --tx_per_key 10 \
    --output_count 10000
# Out:
# 996 keys (9960 transactions) generated...
# 1992 keys (19920 transactions) generated...
# 2988 keys (29880 transactions) generated...
# 3984 keys (39840 transactions) generated...
# 4980 keys (49800 transactions) generated...
# 5976 keys (59760 transactions) generated...
# 6972 keys (69720 transactions) generated...
# 7968 keys (79680 transactions) generated...
# 8964 keys (89640 transactions) generated...
# 9960 keys (99600 transactions) generated...
# Wrote report: transaction_list_20251128205548.txt

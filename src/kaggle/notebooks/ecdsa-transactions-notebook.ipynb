# %% [markdown]
# **Preparing the dataset for work**

# %%
# !cp -r /kaggle/input/d/<user_name>/ecdsa-transactions/* /kaggle/working/

# %%
# !ls -lah /kaggle/working/
# Out:
# total 44K
# drwxr-xr-x 3 root root 4.0K Dec 11 12:26 .
# drwxr-xr-x 5 root root 4.0K Dec 11 12:25 ..
# -rw-r--r-- 1 root root  14K Dec 11 12:26 generate_transactions.py
# -rw-r--r-- 1 root root  13K Dec 11 12:26 secp256k1.py
# drwxr-xr-x 2 root root 4.0K Dec 11 12:26 .virtual_documents

# %% [markdown]
# **Generating ECDSA transactions**

# %%
# !python /kaggle/working/generate_transactions.py \
    --mode test_large \
    --keys 10000 \
    --tx_per_key 1000 \
    --output_count 10000
# Out:
# 1000 keys (1000000 transactions) generated...
# 2000 keys (2000000 transactions) generated...
# 3000 keys (3000000 transactions) generated...
# 4000 keys (4000000 transactions) generated...
# 5000 keys (5000000 transactions) generated...
# 6000 keys (6000000 transactions) generated...
# 7000 keys (7000000 transactions) generated...
# 8000 keys (8000000 transactions) generated...
# 9000 keys (9000000 transactions) generated...
# 10000 keys (10000000 transactions) generated...
# Wrote report: transaction_list_20251211130349.txt

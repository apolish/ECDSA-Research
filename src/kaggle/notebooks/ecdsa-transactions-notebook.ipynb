# %% [markdown]
# **Preparing the dataset for work**

# %%
# !cp -r /kaggle/input/datasets/<user_name>/bitcoin-transactions/* /kaggle/working/

# %%
# !ls -lah /kaggle/input/datasets/<user_name>/bitcoin-transactions
# !ls -lah /kaggle/working/
# Out:
# total 52K
# drwxr-xr-x 2 nobody nogroup    0 Mar 17 19:21 .
# drwxr-xr-x 3 root   root    4.0K Mar 17 19:21 ..
# -rw-r--r-- 1 nobody nogroup 9.1K Mar 17 19:21 find_common_private_key.py
# -rw-r--r-- 1 nobody nogroup  17K Mar 17 19:21 generate_transactions.py
# -rw-r--r-- 1 nobody nogroup  15K Mar 17 19:21 secp256k1.py
# total 60K
# drwxr-xr-x 3 root root 4.0K Mar 17 19:24 .
# drwxr-xr-x 5 root root 4.0K Mar 17 19:21 ..
# -rw-r--r-- 1 root root 9.1K Mar 17 19:24 find_common_private_key.py
# -rw-r--r-- 1 root root  17K Mar 17 19:24 generate_transactions.py
# -rw-r--r-- 1 root root  15K Mar 17 19:24 secp256k1.py
# drwxr-xr-x 2 root root 4.0K Mar 17 19:22 .virtual_documents

# %% [markdown]
# **Generating ECDSA transactions**

# %%
# !python /kaggle/working/generate_transactions.py \
    --mode test_tiny \
    --tx_per_key 9966
# Out:
# 996 keys (9926136 transactions) generated...
# 1992 keys (19852272 transactions) generated...
# 2988 keys (29778408 transactions) generated...
# 3984 keys (39704544 transactions) generated...
# 4980 keys (49630680 transactions) generated...
# 5976 keys (59556816 transactions) generated...
# 6972 keys (69482952 transactions) generated...
# 7968 keys (79409088 transactions) generated...
# 8964 keys (89335224 transactions) generated...
# 9960 keys (99261360 transactions) generated...
# Wrote report: transaction_list_20260317204137.txt
